# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import random
from citipy import citipy
from config import weather_api_key
from config import g_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 649

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | green river
# Processing Record 3 of Set 1 | bambanglipuro
# Processing Record 4 of Set 1 | tabuk
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | ribeira grande
# Processing Record 11 of Set 1 | pilar
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | berlevag
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | bambous virieux
# Processing Record 23 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 1 | port lincoln
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | brae
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | mecca
# Processing Record 30 of Set 1 | itupiranga
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | ushuaia
# Processing Record 33 of Set 1 | zapolyarnyy
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 1 | rawson
# Processing Record 37 of Set 1 | hvolsvollur
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | chikoy
# City not found. Skipping...
# Processing Record 41 of Set 1 | young
# Processing Record 42 of Set 1 | tiksi
# Processing Record 43 of Set 1 | bethel
# Processing Record 44 of Set 1 | hambantota
# Processing Record 45 of Set 1 | kyabe
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | iqaluit
# Processing Record 49 of Set 1 | avera
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | smithers
# Processing Record 2 of Set 2 | mayumba
# Processing Record 3 of Set 2 | cranbrook
# Processing Record 4 of Set 2 | alice springs
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | maceio
# Processing Record 9 of Set 2 | itarema
# Processing Record 10 of Set 2 | indramayu
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | victoria
# Processing Record 13 of Set 2 | tomatlan
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | comodoro rivadavia
# Processing Record 16 of Set 2 | wanaka
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | aguimes
# Processing Record 21 of Set 2 | jiaxing
# Processing Record 22 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | abaete
# Processing Record 25 of Set 2 | finschhafen
# Processing Record 26 of Set 2 | srednekolymsk
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | santa lucia
# Processing Record 29 of Set 2 | domasnea
# Processing Record 30 of Set 2 | aripuana
# Processing Record 31 of Set 2 | sobolevo
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | guerrero negro
# Processing Record 35 of Set 2 | honningsvag
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | halifax
# Processing Record 38 of Set 2 | leningradskiy
# Processing Record 39 of Set 2 | kavieng
# Processing Record 40 of Set 2 | kisaran
# Processing Record 41 of Set 2 | kirovskiy
# Processing Record 42 of Set 2 | ishinomaki
# Processing Record 43 of Set 2 | tautira
# Processing Record 44 of Set 2 | muscat
# Processing Record 45 of Set 2 | mount gambier
# Processing Record 46 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 2 | koyilandi
# City not found. Skipping...
# Processing Record 48 of Set 2 | navabad
# City not found. Skipping...
# Processing Record 49 of Set 2 | aklavik
# Processing Record 50 of Set 2 | codrington
# Processing Record 1 of Set 3 | oranjemund
# Processing Record 2 of Set 3 | takoradi
# Processing Record 3 of Set 3 | blind river
# Processing Record 4 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 3 | thompson
# Processing Record 6 of Set 3 | comrat
# Processing Record 7 of Set 3 | saint-pierre
# Processing Record 8 of Set 3 | khandyga
# Processing Record 9 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 3 | airai
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | sao mateus
# Processing Record 13 of Set 3 | labuhan
# Processing Record 14 of Set 3 | novopokrovka
# Processing Record 15 of Set 3 | henties bay
# Processing Record 16 of Set 3 | piacabucu
# Processing Record 17 of Set 3 | vila franca do campo
# Processing Record 18 of Set 3 | grindavik
# Processing Record 19 of Set 3 | aguas verdes
# Processing Record 20 of Set 3 | salalah
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | shingu
# Processing Record 23 of Set 3 | mao
# Processing Record 24 of Set 3 | tenenkou
# Processing Record 25 of Set 3 | avarua
# Processing Record 26 of Set 3 | marystown
# Processing Record 27 of Set 3 | northam
# Processing Record 28 of Set 3 | eyl
# Processing Record 29 of Set 3 | rio grande
# Processing Record 30 of Set 3 | sao bras de alportel
# Processing Record 31 of Set 3 | naze
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | cap malheureux
# Processing Record 34 of Set 3 | coihaique
# Processing Record 35 of Set 3 | namibe
# Processing Record 36 of Set 3 | atbasar
# Processing Record 37 of Set 3 | kaitangata
# Processing Record 38 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 3 | atar
# Processing Record 40 of Set 3 | hilo
# Processing Record 41 of Set 3 | linxia
# Processing Record 42 of Set 3 | akdepe
# Processing Record 43 of Set 3 | kahului
# Processing Record 44 of Set 3 | pavda
# City not found. Skipping...
# Processing Record 45 of Set 3 | horodyshche
# Processing Record 46 of Set 3 | lusambo
# Processing Record 47 of Set 3 | sola
# Processing Record 48 of Set 3 | turukhansk
# Processing Record 49 of Set 3 | mahebourg
# Processing Record 50 of Set 3 | meiktila
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | monaragala
# Processing Record 3 of Set 4 | katsuura
# Processing Record 4 of Set 4 | pachino
# Processing Record 5 of Set 4 | galveston
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | sturgis
# Processing Record 8 of Set 4 | fortuna
# Processing Record 9 of Set 4 | preobrazheniye
# Processing Record 10 of Set 4 | nyurba
# Processing Record 11 of Set 4 | tashtagol
# Processing Record 12 of Set 4 | jobabo
# Processing Record 13 of Set 4 | tuktoyaktuk
# Processing Record 14 of Set 4 | amapa
# Processing Record 15 of Set 4 | daxian
# City not found. Skipping...
# Processing Record 16 of Set 4 | lompoc
# Processing Record 17 of Set 4 | saint-francois
# Processing Record 18 of Set 4 | san rafael
# Processing Record 19 of Set 4 | conde
# Processing Record 20 of Set 4 | aberystwyth
# Processing Record 21 of Set 4 | anadyr
# Processing Record 22 of Set 4 | port augusta
# Processing Record 23 of Set 4 | lorengau
# Processing Record 24 of Set 4 | bagan
# Processing Record 25 of Set 4 | appiano
# City not found. Skipping...
# Processing Record 26 of Set 4 | bandarbeyla
# Processing Record 27 of Set 4 | saldanha
# Processing Record 28 of Set 4 | sawakin
# Processing Record 29 of Set 4 | sept-iles
# Processing Record 30 of Set 4 | margate
# Processing Record 31 of Set 4 | vostok
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | vaitape
# Processing Record 34 of Set 4 | monrovia
# Processing Record 35 of Set 4 | garden city
# Processing Record 36 of Set 4 | okha
# Processing Record 37 of Set 4 | sturgeon bay
# Processing Record 38 of Set 4 | grimari
# City not found. Skipping...
# Processing Record 39 of Set 4 | cherskiy
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | castro
# Processing Record 42 of Set 4 | sumenep
# Processing Record 43 of Set 4 | chelbasskaya
# Processing Record 44 of Set 4 | bathsheba
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | grajau
# Processing Record 47 of Set 4 | tezu
# Processing Record 48 of Set 4 | gravdal
# Processing Record 49 of Set 4 | mopti
# Processing Record 50 of Set 4 | istiaia
# Processing Record 1 of Set 5 | tuatapere
# Processing Record 2 of Set 5 | longyearbyen
# Processing Record 3 of Set 5 | ponta do sol
# Processing Record 4 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 5 | marawi
# Processing Record 6 of Set 5 | borovskoy
# Processing Record 7 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 5 | khor
# Processing Record 9 of Set 5 | vardo
# Processing Record 10 of Set 5 | magadan
# Processing Record 11 of Set 5 | isangel
# Processing Record 12 of Set 5 | la asuncion
# Processing Record 13 of Set 5 | jumla
# Processing Record 14 of Set 5 | umm kaddadah
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | hirara
# Processing Record 17 of Set 5 | vanimo
# Processing Record 18 of Set 5 | quang ngai
# Processing Record 19 of Set 5 | plettenberg bay
# Processing Record 20 of Set 5 | the valley
# Processing Record 21 of Set 5 | colares
# Processing Record 22 of Set 5 | tual
# Processing Record 23 of Set 5 | launceston
# Processing Record 24 of Set 5 | katherine
# Processing Record 25 of Set 5 | yumen
# Processing Record 26 of Set 5 | parras
# City not found. Skipping...
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | saint george
# Processing Record 29 of Set 5 | kiama
# Processing Record 30 of Set 5 | najran
# Processing Record 31 of Set 5 | mae sai
# Processing Record 32 of Set 5 | ballina
# Processing Record 33 of Set 5 | tutoia
# Processing Record 34 of Set 5 | college
# Processing Record 35 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 5 | tilichiki
# Processing Record 37 of Set 5 | yerbogachen
# Processing Record 38 of Set 5 | lubliniec
# Processing Record 39 of Set 5 | boende
# Processing Record 40 of Set 5 | xiongshi
# City not found. Skipping...
# Processing Record 41 of Set 5 | san quintin
# Processing Record 42 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 5 | yangjiang
# Processing Record 44 of Set 5 | don sak
# Processing Record 45 of Set 5 | maniitsoq
# Processing Record 46 of Set 5 | olavarria
# Processing Record 47 of Set 5 | moose factory
# Processing Record 48 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 5 | abbeville
# Processing Record 50 of Set 5 | savannah bight
# Processing Record 1 of Set 6 | tabou
# Processing Record 2 of Set 6 | ahipara
# Processing Record 3 of Set 6 | aransas pass
# Processing Record 4 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 5 of Set 6 | jinxiang
# Processing Record 6 of Set 6 | djambala
# Processing Record 7 of Set 6 | praxedis guerrero
# Processing Record 8 of Set 6 | padang
# Processing Record 9 of Set 6 | bengkulu
# Processing Record 10 of Set 6 | acapulco
# Processing Record 11 of Set 6 | kidal
# Processing Record 12 of Set 6 | okato
# Processing Record 13 of Set 6 | rio gallegos
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | fraga
# Processing Record 16 of Set 6 | katobu
# Processing Record 17 of Set 6 | mazagao
# Processing Record 18 of Set 6 | nanortalik
# Processing Record 19 of Set 6 | sawtell
# Processing Record 20 of Set 6 | ewa beach
# Processing Record 21 of Set 6 | barrow
# Processing Record 22 of Set 6 | mineral wells
# Processing Record 23 of Set 6 | lavrentiya
# Processing Record 24 of Set 6 | inhambane
# Processing Record 25 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 6 | ancud
# Processing Record 27 of Set 6 | miri
# Processing Record 28 of Set 6 | lahan
# Processing Record 29 of Set 6 | faanui
# Processing Record 30 of Set 6 | tambopata
# Processing Record 31 of Set 6 | tomohon
# Processing Record 32 of Set 6 | bada
# Processing Record 33 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 6 | pershotravneve
# Processing Record 36 of Set 6 | chuy
# Processing Record 37 of Set 6 | tete
# Processing Record 38 of Set 6 | chokurdakh
# Processing Record 39 of Set 6 | da nang
# Processing Record 40 of Set 6 | barentu
# Processing Record 41 of Set 6 | valdosta
# Processing Record 42 of Set 6 | saurimo
# Processing Record 43 of Set 6 | morondava
# Processing Record 44 of Set 6 | guangyuan
# Processing Record 45 of Set 6 | baoqing
# Processing Record 46 of Set 6 | kodiak
# Processing Record 47 of Set 6 | kismayo
# Processing Record 48 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 49 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 6 | buala
# Processing Record 1 of Set 7 | zhuhai
# Processing Record 2 of Set 7 | faya
# Processing Record 3 of Set 7 | wenatchee
# Processing Record 4 of Set 7 | lusaka
# Processing Record 5 of Set 7 | cidreira
# Processing Record 6 of Set 7 | moyale
# Processing Record 7 of Set 7 | shelburne
# Processing Record 8 of Set 7 | bubaque
# Processing Record 9 of Set 7 | husavik
# Processing Record 10 of Set 7 | vila velha
# Processing Record 11 of Set 7 | scarborough
# Processing Record 12 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 7 | bachaquero
# Processing Record 14 of Set 7 | luderitz
# Processing Record 15 of Set 7 | esperance
# Processing Record 16 of Set 7 | booue
# Processing Record 17 of Set 7 | shimoda
# Processing Record 18 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 7 | punta cardon
# Processing Record 20 of Set 7 | hervey bay
# Processing Record 21 of Set 7 | vidim
# Processing Record 22 of Set 7 | teacapan
# Processing Record 23 of Set 7 | nome
# Processing Record 24 of Set 7 | evensk
# Processing Record 25 of Set 7 | niquelandia
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | ocean city
# Processing Record 28 of Set 7 | koroni
# Processing Record 29 of Set 7 | half moon bay
# Processing Record 30 of Set 7 | eureka
# Processing Record 31 of Set 7 | kalaleh
# Processing Record 32 of Set 7 | port hardy
# Processing Record 33 of Set 7 | khani
# Processing Record 34 of Set 7 | dunedin
# Processing Record 35 of Set 7 | vagay
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | ribas do rio pardo
# Processing Record 38 of Set 7 | dingle
# Processing Record 39 of Set 7 | bilibino
# Processing Record 40 of Set 7 | tateyama
# Processing Record 41 of Set 7 | spring valley
# Processing Record 42 of Set 7 | bolotnoye
# Processing Record 43 of Set 7 | haines junction
# Processing Record 44 of Set 7 | east peoria
# Processing Record 45 of Set 7 | sassandra
# Processing Record 46 of Set 7 | nouadhibou
# Processing Record 47 of Set 7 | carberry
# Processing Record 48 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 49 of Set 7 | nishihara
# Processing Record 50 of Set 7 | port blair
# Processing Record 1 of Set 8 | laguna
# Processing Record 2 of Set 8 | huron
# Processing Record 3 of Set 8 | ardino
# Processing Record 4 of Set 8 | korla
# Processing Record 5 of Set 8 | pontian kecil
# Processing Record 6 of Set 8 | outlook
# Processing Record 7 of Set 8 | huarmey
# Processing Record 8 of Set 8 | georgiyevka
# Processing Record 9 of Set 8 | rosarito
# Processing Record 10 of Set 8 | coffs harbour
# Processing Record 11 of Set 8 | pisco
# Processing Record 12 of Set 8 | seddon
# Processing Record 13 of Set 8 | qandahar
# City not found. Skipping...
# Processing Record 14 of Set 8 | solnechnyy
# Processing Record 15 of Set 8 | abha
# Processing Record 16 of Set 8 | bundaberg
# Processing Record 17 of Set 8 | mataram
# Processing Record 18 of Set 8 | cedeno
# Processing Record 19 of Set 8 | pevek
# Processing Record 20 of Set 8 | gardan diwal
# City not found. Skipping...
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | buluang
# Processing Record 23 of Set 8 | mongoumba
# Processing Record 24 of Set 8 | karratha
# Processing Record 25 of Set 8 | cairns
# Processing Record 26 of Set 8 | itoman
# Processing Record 27 of Set 8 | weyburn
# Processing Record 28 of Set 8 | hasaki
# Processing Record 29 of Set 8 | idenao
# Processing Record 30 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 8 | mahajanga
# Processing Record 32 of Set 8 | ninghai
# Processing Record 33 of Set 8 | encheng
# Processing Record 34 of Set 8 | madang
# Processing Record 35 of Set 8 | igrim
# Processing Record 36 of Set 8 | batticaloa
# Processing Record 37 of Set 8 | lensk
# Processing Record 38 of Set 8 | huimanguillo
# Processing Record 39 of Set 8 | la ronge
# Processing Record 40 of Set 8 | envira
# Processing Record 41 of Set 8 | qui nhon
# Processing Record 42 of Set 8 | moree
# Processing Record 43 of Set 8 | gap
# Processing Record 44 of Set 8 | oviedo
# Processing Record 45 of Set 8 | rajanpur
# Processing Record 46 of Set 8 | paita
# Processing Record 47 of Set 8 | lagoa
# Processing Record 48 of Set 8 | urumqi
# Processing Record 49 of Set 8 | tamuin
# Processing Record 50 of Set 8 | zheleznodorozhnyy
# Processing Record 1 of Set 9 | camp verde
# Processing Record 2 of Set 9 | sur
# Processing Record 3 of Set 9 | adamovka
# Processing Record 4 of Set 9 | trelew
# Processing Record 5 of Set 9 | macklin
# Processing Record 6 of Set 9 | grezzana
# Processing Record 7 of Set 9 | laconia
# Processing Record 8 of Set 9 | broome
# Processing Record 9 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 9 | borujerd
# Processing Record 11 of Set 9 | kirakira
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | flinders
# Processing Record 14 of Set 9 | constitucion
# Processing Record 15 of Set 9 | were ilu
# Processing Record 16 of Set 9 | xicotencatl
# Processing Record 17 of Set 9 | teya
# Processing Record 18 of Set 9 | evanston
# Processing Record 19 of Set 9 | labrea
# Processing Record 20 of Set 9 | abeokuta
# Processing Record 21 of Set 9 | yulara
# Processing Record 22 of Set 9 | dauriya
# Processing Record 23 of Set 9 | sao filipe
# Processing Record 24 of Set 9 | maues
# Processing Record 25 of Set 9 | biak
# Processing Record 26 of Set 9 | togur
# Processing Record 27 of Set 9 | puerto escondido
# Processing Record 28 of Set 9 | acari
# Processing Record 29 of Set 9 | verkhneuralsk
# Processing Record 30 of Set 9 | norman wells
# Processing Record 31 of Set 9 | souillac
# Processing Record 32 of Set 9 | pochutla
# Processing Record 33 of Set 9 | putina
# Processing Record 34 of Set 9 | adrar
# Processing Record 35 of Set 9 | clyde river
# Processing Record 36 of Set 9 | fukue
# Processing Record 37 of Set 9 | shu
# Processing Record 38 of Set 9 | osorio
# Processing Record 39 of Set 9 | dicabisagan
# Processing Record 40 of Set 9 | iralaya
# Processing Record 41 of Set 9 | aljezur
# Processing Record 42 of Set 9 | belyy yar
# Processing Record 43 of Set 9 | koboldo
# City not found. Skipping...
# Processing Record 44 of Set 9 | yuza
# Processing Record 45 of Set 9 | gondar
# Processing Record 46 of Set 9 | liverpool
# Processing Record 47 of Set 9 | thunder bay
# Processing Record 48 of Set 9 | jinhua
# Processing Record 49 of Set 9 | messini
# Processing Record 50 of Set 9 | posse
# Processing Record 1 of Set 10 | ko samui
# Processing Record 2 of Set 10 | varkkallai
# Processing Record 3 of Set 10 | kurilsk
# Processing Record 4 of Set 10 | luganville
# Processing Record 5 of Set 10 | hammerfest
# Processing Record 6 of Set 10 | dondo
# Processing Record 7 of Set 10 | kachug
# Processing Record 8 of Set 10 | nantucket
# Processing Record 9 of Set 10 | kutum
# Processing Record 10 of Set 10 | talcahuano
# Processing Record 11 of Set 10 | rosetta
# Processing Record 12 of Set 10 | poum
# Processing Record 13 of Set 10 | marsaxlokk
# Processing Record 14 of Set 10 | balikpapan
# Processing Record 15 of Set 10 | roma
# Processing Record 16 of Set 10 | chara
# Processing Record 17 of Set 10 | piranhas
# Processing Record 18 of Set 10 | buraydah
# Processing Record 19 of Set 10 | turmalina
# Processing Record 20 of Set 10 | kaoma
# Processing Record 21 of Set 10 | kodinsk
# Processing Record 22 of Set 10 | guadalupe
# Processing Record 23 of Set 10 | rochester
# Processing Record 24 of Set 10 | ixtapa
# Processing Record 25 of Set 10 | zambezi
# Processing Record 26 of Set 10 | general roca
# Processing Record 27 of Set 10 | pacific grove
# Processing Record 28 of Set 10 | amahai
# Processing Record 29 of Set 10 | hanford
# Processing Record 30 of Set 10 | barreiras
# Processing Record 31 of Set 10 | praia
# Processing Record 32 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 10 | chacabuco
# Processing Record 35 of Set 10 | curup
# Processing Record 36 of Set 10 | fort abbas
# Processing Record 37 of Set 10 | cobija
# Processing Record 38 of Set 10 | kieta
# Processing Record 39 of Set 10 | badajoz
# Processing Record 40 of Set 10 | myitkyina
# Processing Record 41 of Set 10 | mikhaylovka
# Processing Record 42 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 43 of Set 10 | saint-joseph
# Processing Record 44 of Set 10 | hamilton
# Processing Record 45 of Set 10 | roseburg
# Processing Record 46 of Set 10 | bose
# Processing Record 47 of Set 10 | te anau
# Processing Record 48 of Set 10 | chabahar
# Processing Record 49 of Set 10 | emba
# Processing Record 50 of Set 10 | kawalu
# Processing Record 1 of Set 11 | mount isa
# Processing Record 2 of Set 11 | stanger
# Processing Record 3 of Set 11 | saint-augustin
# Processing Record 4 of Set 11 | farafangana
# Processing Record 5 of Set 11 | ormara
# Processing Record 6 of Set 11 | dongying
# Processing Record 7 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 11 | burica
# City not found. Skipping...
# Processing Record 9 of Set 11 | christchurch
# Processing Record 10 of Set 11 | vilhena
# Processing Record 11 of Set 11 | rock springs
# Processing Record 12 of Set 11 | bay roberts
# Processing Record 13 of Set 11 | hobyo
# Processing Record 14 of Set 11 | cacu
# Processing Record 15 of Set 11 | korem
# Processing Record 16 of Set 11 | verkhnevilyuysk
# Processing Record 17 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 11 | nufaru
# Processing Record 19 of Set 11 | waipawa
# Processing Record 20 of Set 11 | krasnoselkup
# Processing Record 21 of Set 11 | bahia blanca
# Processing Record 22 of Set 11 | klaksvik
# Processing Record 23 of Set 11 | sovetskiy
# Processing Record 24 of Set 11 | egvekinot
# Processing Record 25 of Set 11 | ulladulla
# Processing Record 26 of Set 11 | bar harbor
# Processing Record 27 of Set 11 | pinhao
# Processing Record 28 of Set 11 | kon tum
# Processing Record 29 of Set 11 | lakatoro
# Processing Record 30 of Set 11 | ambilobe
# Processing Record 31 of Set 11 | beira
# Processing Record 32 of Set 11 | willmar
# Processing Record 33 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 11 | lannion
# Processing Record 35 of Set 11 | aquiraz
# Processing Record 36 of Set 11 | krasnovishersk
# Processing Record 37 of Set 11 | tiznit
# Processing Record 38 of Set 11 | paracuru
# Processing Record 39 of Set 11 | marevo
# Processing Record 40 of Set 11 | porto nacional
# Processing Record 41 of Set 11 | canaries
# Processing Record 42 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 43 of Set 11 | igarka
# Processing Record 44 of Set 11 | cabra
# Processing Record 45 of Set 11 | garowe
# Processing Record 46 of Set 11 | lumding
# Processing Record 47 of Set 11 | zhigansk
# Processing Record 48 of Set 11 | nyrob
# Processing Record 49 of Set 11 | liepaja
# Processing Record 50 of Set 11 | solano
# Processing Record 1 of Set 12 | lacarak
# Processing Record 2 of Set 12 | capinota
# Processing Record 3 of Set 12 | carutapera
# Processing Record 4 of Set 12 | paraiso
# Processing Record 5 of Set 12 | cockburn town
# Processing Record 6 of Set 12 | nanning
# Processing Record 7 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 12 | mizan teferi
# Processing Record 9 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 12 | arman
# Processing Record 11 of Set 12 | cajati
# Processing Record 12 of Set 12 | ovalle
# Processing Record 13 of Set 12 | usila
# City not found. Skipping...
# Processing Record 14 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 12 | bull savanna
# Processing Record 16 of Set 12 | novikovo
# Processing Record 17 of Set 12 | belmonte
# Processing Record 18 of Set 12 | hansot
# Processing Record 19 of Set 12 | tura
# Processing Record 20 of Set 12 | shieli
# Processing Record 21 of Set 12 | uray
# Processing Record 22 of Set 12 | tankara
# Processing Record 23 of Set 12 | kichera
# Processing Record 24 of Set 12 | aitape
# Processing Record 25 of Set 12 | viedma
# Processing Record 26 of Set 12 | bonthe
# Processing Record 27 of Set 12 | vanavara
# Processing Record 28 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 12 | aswan
# Processing Record 30 of Set 12 | cabo san lucas
# Processing Record 31 of Set 12 | tokur
# Processing Record 32 of Set 12 | provideniya
# Processing Record 33 of Set 12 | namatanai
# Processing Record 34 of Set 12 | ust-kulom
# Processing Record 35 of Set 12 | sabla
# Processing Record 36 of Set 12 | bara
# Processing Record 37 of Set 12 | lerwick
# Processing Record 38 of Set 12 | hami
# Processing Record 39 of Set 12 | marsa matruh
# Processing Record 40 of Set 12 | boa viagem
# Processing Record 41 of Set 12 | beni
# Processing Record 42 of Set 12 | kaele
# Processing Record 43 of Set 12 | marsh harbour
# Processing Record 44 of Set 12 | saint-georges
# Processing Record 45 of Set 12 | bilma
# Processing Record 46 of Set 12 | alofi
# Processing Record 47 of Set 12 | sabang
# Processing Record 48 of Set 12 | kudahuvadhoo
# Processing Record 49 of Set 12 | palmer
# Processing Record 50 of Set 12 | barcelona
# Processing Record 1 of Set 13 | omboue
# Processing Record 2 of Set 13 | vestmanna
# Processing Record 3 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 13 | matay
# Processing Record 5 of Set 13 | oistins
# Processing Record 6 of Set 13 | anaconda
# Processing Record 7 of Set 13 | challans
# Processing Record 8 of Set 13 | santa cruz do capibaribe
# Processing Record 9 of Set 13 | vierzon
# Processing Record 10 of Set 13 | kabugao
# Processing Record 11 of Set 13 | camara de lobos
# Processing Record 12 of Set 13 | lasa
# Processing Record 13 of Set 13 | umm lajj
# Processing Record 14 of Set 13 | mayo
# Processing Record 15 of Set 13 | hauterive
# Processing Record 16 of Set 13 | altamont
# Processing Record 17 of Set 13 | orchard homes
# Processing Record 18 of Set 13 | luwingu
# Processing Record 19 of Set 13 | rameswaram
# Processing Record 20 of Set 13 | yellapur
# Processing Record 21 of Set 13 | sao felix do xingu
# Processing Record 22 of Set 13 | saiha
# Processing Record 23 of Set 13 | iquitos
# Processing Record 24 of Set 13 | kasongo-lunda
# Processing Record 25 of Set 13 | zyryanka
# Processing Record 26 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 13 | pringsewu
# Processing Record 28 of Set 13 | chenzhou
# Processing Record 29 of Set 13 | tessalit
# Processing Record 30 of Set 13 | touros
# Processing Record 31 of Set 13 | saint anthony
# Processing Record 32 of Set 13 | gigmoto
# Processing Record 33 of Set 13 | gari
# Processing Record 34 of Set 13 | jabiru
# City not found. Skipping...
# Processing Record 35 of Set 13 | isakly
# Processing Record 36 of Set 13 | galle
# Processing Record 37 of Set 13 | himora
# City not found. Skipping...
# Processing Record 38 of Set 13 | calderitas
# Processing Record 39 of Set 13 | ekibastuz
# Processing Record 40 of Set 13 | tchollire
# Processing Record 41 of Set 13 | miyazu
# Processing Record 42 of Set 13 | glenwood springs
# Processing Record 43 of Set 13 | nobres
# Processing Record 44 of Set 13 | sainte-rose
# Processing Record 45 of Set 13 | pangkalanbuun
# Processing Record 46 of Set 13 | lata
# Processing Record 47 of Set 13 | sarkand
# Processing Record 48 of Set 13 | acajutla
# Processing Record 49 of Set 13 | mezen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# challenge objective 
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Green River      US  41.5286 -109.4662     88.20        28           0
# 1    Bambanglipuro      ID  -7.9500  110.2833     75.54        87          46
# 2            Tabuk      PH  17.4189  121.4443     75.07        84          74
# 3          Rikitea      PF -23.1203 -134.9692     74.08        78           0
# 4            Vaini      TO -21.2000 -175.2000     66.36        88          75
# ..             ...     ...      ...       ...       ...       ...         ...
# 586  Pangkalanbuun      ID  -2.6833  111.6167     74.16        98          92
# 587           Lata      PT  40.1629   -8.3327     88.03        53           0
# 588        Sarkand      KZ  45.4100   79.9186     60.98        50          89
# 589       Acajutla      SV  13.5928  -89.8275     91.80        71         100
# 590          Mezen      RU  65.8522   44.2400     61.86        99         100
#
#      Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0          3.00           clear sky            0.0              0
# 1          7.18    scattered clouds            0.0              0
# 2          1.50       broken clouds            0.0              0
# 3          7.09           clear sky            0.0              0
# 4          6.91          light rain            0.0              0
# ..          ...                 ...            ...            ...
# 586        2.75     overcast clouds            0.0              0
# 587        4.05           clear sky            0.0              0
# 588        5.70     overcast clouds            0.0              0
# 589        6.15     overcast clouds            0.0              0
# 590        4.83     overcast clouds            0.0              0
#
# [591 rows x 11 columns]

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 9        Mataura      NZ -46.1927  168.8643     42.48        95         100
# 21     Upernavik      GL  72.7868  -56.1549     43.45        93         100
# 28       Ushuaia      AR -54.8000  -68.3000     37.06        93          75
# 34  Punta Arenas      CL -53.1500  -70.9167     51.91        62          40
# 42       Iqaluit      CA  63.7506  -68.5145     44.33       100          75
# 57         Kapaa      US  22.0752 -159.3190     82.72        72          40
# 59        Wanaka      NZ -44.7000  169.1500     45.10        99          78
# 64       Jiaxing      CN  30.7522  120.7500     77.02        97         100
# 73     Ilulissat      GL  69.2167  -51.1000     53.62        66          75
# 86       Aklavik      CA  68.2191 -135.0107     46.40        81          75
#
#     Wind Speed      Current Description  Rain (inches)  Snow (inches)
# 9        11.43               light rain           0.68              0
# 21        9.64            moderate rain           1.04              0
# 28       10.36  light intensity drizzle           0.50              0
# 34       31.07               light rain           0.35              0
# 42        9.22               light rain           0.25              0
# 57        4.00               light rain           0.11              0
# 59        1.99               light rain           0.12              0
# 64        7.14               light rain           0.27              0
# 73       13.80               light rain           0.33              0
# 86        4.61               light rain           0.33              0

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(10)
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
